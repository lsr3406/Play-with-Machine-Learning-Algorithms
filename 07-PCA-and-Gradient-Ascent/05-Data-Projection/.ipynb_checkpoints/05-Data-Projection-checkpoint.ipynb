# %% [markdown]
# # 从高维数据向低维数据的映射

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((1000, 2))
X[:, 0] = np.random.uniform(-1, 1, (1000,))
X[:, 1] = 0.75 * X[:, 0] + np.sin(12.56 * X[:, 0]) * 0.2
X += np.random.normal(1, 0.02, (1000,2))

plt.scatter(X[:,0], X[:, 1], marker=".")
plt.show()

# %%
from playML.PCA import PCA

# %%
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[ 0.80707978,  0.5904424 ],
#        [-0.6001382 ,  0.79989633]])

# %%
X_reduced = pca.transform(X)
plt.scatter(X_reduced[:,0], X_reduced[:, 1], marker=".")
plt.show()

# %%
X_restore = pca.inverse_transform(X_reduced)
plt.scatter(X_restore[:,0], X_restore[:, 1], marker=".")
plt.show()

# %% [markdown]
# #### 降噪实验

# %%
pca = PCA(n_components=1)
pca.fit(X)
X_reduced = pca.transform(X)
X_redu
